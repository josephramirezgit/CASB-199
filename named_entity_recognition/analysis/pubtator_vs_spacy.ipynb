# %% [markdown]
# # Extract only gene or gene product entities

# %% [markdown]
# Begin by cleaning the data and only extracting entities considered gene or gene products. Pubtator classifies what we want as "gene" whereas scispacy classifies what we want as "GENE_OR_GENE_PRODUCTS"

# %%
import pandas as pd

# %%
# initalize paths
pubtator_entities_path = "../results/pubtator_abstract_entities.csv"
scispacy_entities_path = "../results/scispacy_abstract_entities.csv"

# %%
# initalize dataframes
pubtator_entities = pd.read_csv(pubtator_entities_path, sep="\t")
scispacy_entities = pd.read_csv(scispacy_entities_path)
scispacy_entities = scispacy_entities.drop(columns=["Unnamed: 0"], axis=1)

# %%
# rename column for consitency
scispacy_entities = scispacy_entities.rename({"entity-labels":"entity-type"}, axis=1)

# %%
# ensure proper formatting
pubtator_entities
# Out:
#                                                 entity entity-type      pmid
# 0                            hallmark of heart failure     Disease  34806902
# 1                                               murine     Species  34806902
# 2                                              ADAMTS5        Gene  34806902
# 3    a disintegrin and metalloproteinase with throm...        Gene  34806902
# 4                                              ADAMTS5        Gene  34806902
# ..                                                 ...         ...       ...
# 141                                         transgelin        Gene  29484645
# 142                                              human     Species  29133944
# 143                                              death     Disease  29133944
# 144                                              human     Species  29133944
# 145                                atrial fibrillation     Disease  29133944
#
# [146 rows x 3 columns]

# %%
# ensure proper formatting
scispacy_entities
# Out:
#                          entity           entity-type      pmid
# 0          extracellular matrix    CELLULAR_COMPONENT  34806902
# 1                           ECM    CELLULAR_COMPONENT  34806902
# 2                         heart                 ORGAN  34806902
# 3    murine cardiac fibroblasts              ORGANISM  34806902
# 4                       ADAMTS5  GENE_OR_GENE_PRODUCT  34806902
# ..                          ...                   ...       ...
# 195                cell surface    CELLULAR_COMPONENT  29133944
# 196                       heart                 ORGAN  29133944
# 197               mitochondrial    CELLULAR_COMPONENT  29133944
# 198                       heart                 ORGAN  29133944
# 199                       heart                 ORGAN  29133944
#
# [200 rows x 3 columns]

# %%
# only save proteins 
pubtator_entities_proteins = pubtator_entities[pubtator_entities["entity-type"] == "Gene"]
scispacy_entites_proteins = scispacy_entities[scispacy_entities["entity-type"] == "GENE_OR_GENE_PRODUCT"]

# %%
# inspect results
pubtator_entities_proteins
# Out:
#                                                 entity entity-type      pmid
# 2                                              ADAMTS5        Gene  34806902
# 3    a disintegrin and metalloproteinase with throm...        Gene  34806902
# 4                                              ADAMTS5        Gene  34806902
# 6                                              ADAMTS5        Gene  34806902
# 8                                              ADAMTS5        Gene  34806902
# 9                                              Adamts5        Gene  34806902
# 15                                              Ang II        Gene  34806902
# 16                                             Adamts5        Gene  34806902
# 18                                              Ang II        Gene  34806902
# 20                                     integrin beta 1        Gene  34806902
# 21                                           filamin A        Gene  34806902
# 22                                         connexin 43        Gene  34806902
# 23                                             Adamts5        Gene  34806902
# 25                                              Ang II        Gene  34806902
# 28                           beta1-adrenergic receptor        Gene  34806902
# 36                                               HINT1        Gene  34098726
# 37        histidine triad nucleotide-binding protein 1        Gene  34098726
# 40                                               HINT1        Gene  34098726
# 43                                               Hint1        Gene  34098726
# 45                                               HINT1        Gene  34098726
# 49                                               Hint1        Gene  34098726
# 50                                                cTnT        Gene  34098726
# 51                                               HINT1        Gene  34098726
# 53                                               Hoxa5        Gene  34098726
# 54                                         homeobox A5        Gene  34098726
# 55                                               HINT1        Gene  34098726
# 57                                               HOXA5        Gene  34098726
# 58                                               HINT1        Gene  34098726
# 59                                               HOXA5        Gene  34098726
# 60                                               HINT1        Gene  34098726
# 65                                               Hint1        Gene  34098726
# 68                                               HINT1        Gene  34098726
# 70                                               HOXA5        Gene  34098726
# 71                                               HINT1        Gene  34098726
# 72                                               HINT1        Gene  34098726
# 73                                               HOXA5        Gene  34098726
# 74                                               Hoxa5        Gene  34098726
# 76                                            TGF-beta        Gene  34098726
# 77                                               HINT1        Gene  34098726
# 78                                                 MEK        Gene  34098726
# 79                                                 ERK        Gene  34098726
# 80                                                 YY1        Gene  34098726
# 81                                               HOXA5        Gene  34098726
# 83                                               HINT1        Gene  34098726
# 85                                               HOXA5        Gene  34098726
# 86                                               HINT1        Gene  34098726
# 89                                                 PLN        Gene  33998164
# 96                                                 PLN        Gene  33998164
# 100                                                PLN        Gene  33998164
# 104                                                PLN        Gene  33998164
# 120                     serine proteinase inhibitor A3        Gene  31670476
# 121                                           Serpina3        Gene  31670476
# 125                                           Serpina3        Gene  31670476
# 127                                           Serpina3        Gene  31670476
# 135                               myosin light chain 4        Gene  29484645
# 136     myosin regulatory light chain 2-atrial isoform        Gene  29484645
# 137                               myosin light chain 3        Gene  29484645
# 138  myosin regulatory light chain 2-ventricular/ca...        Gene  29484645
# 141                                         transgelin        Gene  29484645

# %%
# inspect results
scispacy_entites_proteins
# Out:
#                                                 entity           entity-type  \
# 4                                              ADAMTS5  GENE_OR_GENE_PRODUCT
# 5                                          disintegrin  GENE_OR_GENE_PRODUCT
# 6                              thrombospondin motifs 5  GENE_OR_GENE_PRODUCT
# 7                                              ADAMTS5  GENE_OR_GENE_PRODUCT
# 8                   chondroitin sulphate proteoglycans  GENE_OR_GENE_PRODUCT
# ..                                                 ...                   ...
# 168                               myosin light chain 3  GENE_OR_GENE_PRODUCT
# 169  myosin regulatory light chain 2-ventricular/ca...  GENE_OR_GENE_PRODUCT
# 174                                 tricarboxylic acid  GENE_OR_GENE_PRODUCT
# 176                                   fatty acid omega  GENE_OR_GENE_PRODUCT
# 180                                         transgelin  GENE_OR_GENE_PRODUCT
#
#          pmid
# 4    34806902
# 5    34806902
# 6    34806902
# 7    34806902
# 8    34806902
# ..        ...
# 168  29484645
# 169  29484645
# 174  29484645
# 176  29484645
# 180  29484645
#
# [84 rows x 3 columns]

# %% [markdown]
# # Visualize counts

# %% [markdown]
# Tabulate value counts

# %%
pubtator_entities_proteins.groupby(["pmid"])["entity-type"].value_counts()
# Out:
# pmid      entity-type
# 29484645  Gene            5
# 31670476  Gene            4
# 33998164  Gene            4
# 34098726  Gene           31
# 34806902  Gene           15
# Name: entity-type, dtype: int64

# %%
scispacy_entites_proteins.groupby(["pmid"])["entity-type"].value_counts()
# Out:
# pmid      entity-type
# 29484645  GENE_OR_GENE_PRODUCT     8
# 31670476  GENE_OR_GENE_PRODUCT     3
# 33998164  GENE_OR_GENE_PRODUCT     8
# 34098726  GENE_OR_GENE_PRODUCT    33
# 34806902  GENE_OR_GENE_PRODUCT    32
# Name: entity-type, dtype: int64

# %% [markdown]
# Explore proteins found in PMID: 34098726

# %%
pubtator_entities_proteins.groupby(["pmid"]).value_counts()
# Out:
# pmid      entity                                                              entity-type
# 29484645  myosin light chain 3                                                Gene            1
#           myosin light chain 4                                                Gene            1
#           transgelin                                                          Gene            1
#           myosin regulatory light chain 2-ventricular/cardiac muscle isoform  Gene            1
#           myosin regulatory light chain 2-atrial isoform                      Gene            1
# 31670476  Serpina3                                                            Gene            3
#           serine proteinase inhibitor A3                                      Gene            1
# 33998164  PLN                                                                 Gene            4
# 34098726  HINT1                                                               Gene           13
#           HOXA5                                                               Gene            6
#           Hint1                                                               Gene            3
#           Hoxa5                                                               Gene            2
#           histidine triad nucleotide-binding protein 1                        Gene            1
#           homeobox A5                                                         Gene            1
#           MEK                                                                 Gene            1
#           cTnT                                                                Gene            1
#           YY1                                                                 Gene            1
#           TGF-beta                                                            Gene            1
#           ERK                                                                 Gene            1
# 34806902  ADAMTS5                                                             Gene            4
#           Ang II                                                              Gene            3
#           Adamts5                                                             Gene            3
#           filamin A                                                           Gene            1
#           connexin 43                                                         Gene            1
#           beta1-adrenergic receptor                                           Gene            1
#           a disintegrin and metalloproteinase with thrombospondin motifs 5    Gene            1
#           integrin beta 1                                                     Gene            1
# dtype: int64

# %%
scispacy_entites_proteins.groupby(["pmid"]).value_counts()
# Out:
# pmid      entity                                                                                    entity-type
# 29484645  fatty acid omega                                                                          GENE_OR_GENE_PRODUCT     1
#           myosin light chain 3                                                                      GENE_OR_GENE_PRODUCT     1
#           myosin light chain 4                                                                      GENE_OR_GENE_PRODUCT     1
#           myosin regulatory light chain 2-atrial                                                    GENE_OR_GENE_PRODUCT     1
#           myosin regulatory light chain 2-ventricular/cardiac                                       GENE_OR_GENE_PRODUCT     1
#           transgelin                                                                                GENE_OR_GENE_PRODUCT     1
#           tricarboxylic acid                                                                        GENE_OR_GENE_PRODUCT     1
#           tropomyosin alpha-3 chain                                                                 GENE_OR_GENE_PRODUCT     1
# 31670476  Serpina3                                                                                  GENE_OR_GENE_PRODUCT     2
#           serine proteinase inhibitor A3                                                            GENE_OR_GENE_PRODUCT     1
# 33998164  HINT1                                                                                     GENE_OR_GENE_PRODUCT    12
#           HOXA5                                                                                     GENE_OR_GENE_PRODUCT     5
#           Hint1                                                                                     GENE_OR_GENE_PRODUCT     2
#           Hoxa5                                                                                     GENE_OR_GENE_PRODUCT     2
#           transforming growth factor beta) signal                                                   GENE_OR_GENE_PRODUCT     1
#           Cardiac-specific                                                                          GENE_OR_GENE_PRODUCT     1
#           HINT1 mice                                                                                GENE_OR_GENE_PRODUCT     1
#           PKCbeta1                                                                                  GENE_OR_GENE_PRODUCT     1
#           TGF-beta                                                                                  GENE_OR_GENE_PRODUCT     1
#           adeno-associated virus 9                                                                  GENE_OR_GENE_PRODUCT     1
#           cTnT                                                                                      GENE_OR_GENE_PRODUCT     1
#           cardiac-specific                                                                          GENE_OR_GENE_PRODUCT     1
#           homeobox A5                                                                               GENE_OR_GENE_PRODUCT     1
#           mitogen-activated protein kinase/extracellular signal-regulated kinase kinase/yin yang 1  GENE_OR_GENE_PRODUCT     1
#           nucleotide-binding protein 1                                                              GENE_OR_GENE_PRODUCT     1
#           protein kinase C beta type 1) membrane                                                    GENE_OR_GENE_PRODUCT     1
# 34098726  ER                                                                                        GENE_OR_GENE_PRODUCT     3
#           PLN                                                                                       GENE_OR_GENE_PRODUCT     3
#           ER/mitochondria                                                                           GENE_OR_GENE_PRODUCT     2
# 34806902  versican                                                                                  GENE_OR_GENE_PRODUCT     8
#           ADAMTS5                                                                                   GENE_OR_GENE_PRODUCT     4
#           Ang II                                                                                    GENE_OR_GENE_PRODUCT     3
#           Versican                                                                                  GENE_OR_GENE_PRODUCT     2
#           thrombospondin motifs 5                                                                   GENE_OR_GENE_PRODUCT     1
#           beta1-adrenergic receptor                                                                 GENE_OR_GENE_PRODUCT     1
#           chondroitin sulphate proteoglycans                                                        GENE_OR_GENE_PRODUCT     1
#           collagen                                                                                  GENE_OR_GENE_PRODUCT     1
#           hyaluronic acid                                                                           GENE_OR_GENE_PRODUCT     1
#           angiotensin II                                                                            GENE_OR_GENE_PRODUCT     1
#           CSPGs                                                                                     GENE_OR_GENE_PRODUCT     1
#           connexin                                                                                  GENE_OR_GENE_PRODUCT     1
#           Adamts5 Cat mice                                                                          GENE_OR_GENE_PRODUCT     1
#           Adamts5 Cat                                                                               GENE_OR_GENE_PRODUCT     1
#           Adamts5                                                                                   GENE_OR_GENE_PRODUCT     1
#           disintegrin                                                                               GENE_OR_GENE_PRODUCT     1
#           ADAMTS                                                                                    GENE_OR_GENE_PRODUCT     1
#           filamin A                                                                                 GENE_OR_GENE_PRODUCT     1
#           integrin beta 1                                                                           GENE_OR_GENE_PRODUCT     1
# dtype: int64
